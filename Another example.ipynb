# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
dataframe = pd.read_csv("ecoli.data.txt", delim_whitespace=True,header=None) # math studentssep=r"\s*"

# %% [markdown]
# ## Take a Look

# %% [markdown]
# Before doing anything to our dataset we want to explore it.

# %%
#dataframe[0:5] 
dataframe.head(5)
# Out:
#             0     1     2     3    4     5     6     7   8
# 0   AAT_ECOLI  0.49  0.29  0.48  0.5  0.56  0.24  0.35  cp
# 1  ACEA_ECOLI  0.07  0.40  0.48  0.5  0.54  0.35  0.44  cp
# 2  ACEK_ECOLI  0.56  0.40  0.48  0.5  0.49  0.37  0.46  cp
# 3  ACKA_ECOLI  0.59  0.49  0.48  0.5  0.52  0.45  0.36  cp
# 4   ADI_ECOLI  0.23  0.32  0.48  0.5  0.55  0.25  0.35  cp

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 336 entries, 0 to 335
# Data columns (total 9 columns):
# 0    336 non-null object
# 1    336 non-null float64
# 2    336 non-null float64
# 3    336 non-null float64
# 4    336 non-null float64
# 5    336 non-null float64
# 6    336 non-null float64
# 7    336 non-null float64
# 8    336 non-null object
# dtypes: float64(7), object(2)

# %% [markdown]
# <h2>Get columns's information </h2>

# %%
dataframe.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %% [markdown]
# Oops! Change columns names
#
#
#   1.  Sequence Name: Accession number for the SWISS-PROT database
#   2.  mcg: McGeoch's method for signal sequence recognition.
#   3.  gvh: von Heijne's method for signal sequence recognition.
#   4.  lip: von Heijne's Signal Peptidase II consensus sequence score.
#            Binary attribute.
#   5.  chg: Presence of charge on N-terminus of predicted lipoproteins.
# 	   Binary attribute.
#   6.  aac: score of discriminant analysis of the amino acid content of
# 	   outer membrane and periplasmic proteins.
#   7. alm1: score of the ALOM membrane spanning region prediction program.
#   8. alm2: score of ALOM program after excluding putative cleavable signal
# 	   regions from the sequence.

# %%
dataframe.columns=["seq","mcg","gvh","lip","cgh","aac","alm1","alm2","class"]

# %% [markdown]
# Specific column

# %%
dataframe.head(5)
# Out:
#           seq   mcg   gvh   lip  cgh   aac  alm1  alm2 class
# 0   AAT_ECOLI  0.49  0.29  0.48  0.5  0.56  0.24  0.35    cp
# 1  ACEA_ECOLI  0.07  0.40  0.48  0.5  0.54  0.35  0.44    cp
# 2  ACEK_ECOLI  0.56  0.40  0.48  0.5  0.49  0.37  0.46    cp
# 3  ACKA_ECOLI  0.59  0.49  0.48  0.5  0.52  0.45  0.36    cp
# 4   ADI_ECOLI  0.23  0.32  0.48  0.5  0.55  0.25  0.35    cp

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(dataframe, alpha=0.2,  diagonal='hist',figsize=(10,10))
plt.show()
